# %% [markdown]
# # FACE RECOGNITION WITH PCA

# %% [markdown]
# ## Import necessary libraries

# %%
import numpy as np
import scann
import matplotlib.pyplot as plt
from skimage import io, transform, color
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.datasets import fetch_olivetti_faces

# %% [markdown]
# ## Obtain the dataset

# %%
faces = fetch_olivetti_faces()
targets, data = faces["target"], faces["data"]

# %% [markdown]
# ## Split dataset into train and test

# %%
x_train, x_test, y_train, y_test = train_test_split(
    data, 
    targets, 
    stratify = targets,
    test_size = 0.2,
    random_state = 0
)

# %% [markdown]
# ## Explore original images

# %%
def show_orignal_images(pixels):
    fig, axes = plt.subplots(6, 10, figsize=(11, 7), subplot_kw={'xticks':[], 'yticks':[]})
    for i, ax in enumerate(axes.flat):
        ax.imshow(np.array(pixels)[i].reshape(64, 64), cmap='gray')
    plt.show()

# %%
show_orignal_images(x_train)

# %% [markdown]
# ## Preprocess datasets

# %%
pca = PCA(n_components = 0.95)
pca.fit(x_train)
# Out:
# PCA(n_components=0.95)

# %% [markdown]
# ## Explore variance trend

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %% [markdown]
# ## Explore Eigenfaces

# %%
def show_eigenfaces(pca):
    fig, axes = plt.subplots(3, 8, figsize=(9, 4), subplot_kw={'xticks':[], 'yticks':[]})
    for i, ax in enumerate(axes.flat):
        ax.imshow(pca.components_[i].reshape(64, 64), cmap='gray')
        ax.set_title("PC " + str(i+1))
    plt.show()

# %%
show_eigenfaces(pca)

# %% [markdown]
# ## Transform data

# %%
x_train = pca.transform(x_train);
x_test = pca.transform(x_test);

# %% [markdown]
# ## Classifying as recognized and not-recognized by clustering

# %%
def GetNeighbors(x_train, y_train, x_test, k):
    searcher = scann.scann_ops_pybind.builder(
        x_train, 
        k, 
        "dot_product"
    ).tree(
        num_leaves = 10, 
        num_leaves_to_search = 300, 
        training_sample_size = 500
    ).score_ah(
        2, 
        anisotropic_quantization_threshold = 0.2
    ).reorder(30).build()
    
    neighbors, distances = searcher.search_batched(x_test)
    categories = np.array(y_train)
    
    neighbors = categories[neighbors]
    
    return neighbors, distances

# %%
x_train = x_train/np.sqrt(np.sum(np.square(x_train), axis = 1, keepdims = True))
x_train
# Out:
# array([[-3.9828914e-01,  2.4089710e-01,  2.4267897e-01, ...,
#          4.8697192e-02, -2.2311565e-02, -8.5391283e-02],
#        [-4.8544565e-01, -4.9775440e-01, -3.5212770e-01, ...,
#         -1.2129142e-03, -2.2363039e-02, -1.5648872e-02],
#        [ 7.5056440e-01,  3.7094361e-01, -1.2671740e-01, ...,
#         -3.2284413e-02, -2.2267431e-02,  2.3632469e-02],
#        ...,
#        [-4.2493016e-01,  2.2527337e-01, -3.8091376e-01, ...,
#         -2.5090601e-02,  5.6870390e-02, -3.9798815e-02],
#        [ 1.7444520e-01, -2.3557690e-01,  1.4498739e-01, ...,
#         -3.9264418e-02, -1.1861455e-02, -7.4736858e-03],
#        [-2.4306525e-03, -5.4339971e-02,  7.0387608e-01, ...,
#         -5.5446872e-03, -7.4946752e-04,  4.9199171e-02]], dtype=float32)

# %%
x_test = x_test/np.sqrt(np.sum(np.square(x_test), axis = 1, keepdims = True))
x_test
# Out:
# array([[-0.6521135 , -0.46783686,  0.03729744, ...,  0.01728846,
#          0.01911018, -0.00387881],
#        [-0.31465966, -0.55936694, -0.2571229 , ...,  0.01750799,
#          0.02421471, -0.00813063],
#        [ 0.21818477, -0.1650177 ,  0.33520785, ...,  0.04817883,
#          0.00479795,  0.01735266],
#        ...,
#        [-0.10694456, -0.2415716 , -0.6509594 , ..., -0.04158683,
#         -0.03756017, -0.00801475],
#        [-0.18845294, -0.24605429, -0.67590564, ..., -0.0086048 ,
#         -0.02688279, -0.03563562],
#        [ 0.15875258, -0.58315927,  0.12792481, ...,  0.01158976,
#         -0.01474725, -0.01090396]], dtype=float32)

# %%
neighbors, distances = GetNeighbors(x_train, y_train, x_test, 3)

# %%
neighbors
# Out:
# array([[ 7,  7,  7],
#        [10, 10, 10],
#        [11, 11, 11],
#        [39,  0,  3],
#        [ 8,  8, 11],
#        [15,  0,  0],
#        [23, 23, 23],
#        [11, 11, 11],
#        [27, 27, 27],
#        [20, 20, 20],
#        [39,  3, 15],
#        [ 2,  0,  4],
#        [22,  3,  7],
#        [ 8,  8,  8],
#        [31, 31, 31],
#        [32, 32, 32],
#        [ 0, 39, 16],
#        [29, 29, 29],
#        [33, 33, 33],
#        [ 6,  6,  6],
#        [ 2, 22, 22],
#        [18, 18, 18],
#        [ 5,  5,  5],
#        [26, 26, 26],
#        [39, 39,  2],
#        [28, 23, 12],
#        [21, 21, 21],
#        [34, 34,  4],
#        [30, 30, 30],
#        [28, 28, 28],
#        [22, 11, 17],
#        [17, 17, 17],
#        [13, 13, 13],
#        [ 3, 22,  9],
#        [19, 19, 19],
#        [37, 37, 39],
#        [ 0,  0, 15],
#        [ 9,  9, 11],
#        [38, 38, 38],
#        [23, 23, 23],
#        [22, 22,  8],
#        [34, 34, 34],
#        [36, 36, 36],
#        [30, 30, 30],
#        [35, 35, 35],
#        [27, 27, 27],
#        [22,  5,  5],
#        [39,  5,  5],
#        [36, 36, 36],
#        [15,  0, 15],
#        [38, 38, 38],
#        [ 9,  9,  9],
#        [12, 24, 39],
#        [25,  2, 25],
#        [12, 12, 12],
#        [17, 17, 17],
#        [35, 35, 23],
#        [31, 31, 31],
#        [29, 29, 29],
#        [16, 16,  0],
#        [19, 19, 19],
#        [18, 18, 18],
#        [16, 16, 16],
#        [20, 38, 38],
#        [ 6, 35, 35],
#        [ 5,  5,  5],
#        [ 1,  1,  1],
#        [ 4,  4,  4],
#        [33, 33, 33],
#        [24, 24, 24],
#        [26, 26, 26],
#        [13, 13, 13],
#        [14, 14, 14],
#        [21, 21, 21],
#        [10, 10, 10],
#        [32, 32, 32],
#        [37, 37, 37],
#        [ 1,  1,  1],
#        [14, 14, 14],
#        [24, 24, 24]])

# %%
distances
# Out:
# array([[0.94743973, 0.89086217, 0.8801197 ],
#        [0.8395928 , 0.73357594, 0.72681105],
#        [0.74706227, 0.6955524 , 0.53150016],
#        [0.93787736, 0.8846155 , 0.8025366 ],
#        [0.85506153, 0.7351719 , 0.6077403 ],
#        [0.9522641 , 0.66523594, 0.5938309 ],
#        [0.9927821 , 0.95481294, 0.9130997 ],
#        [0.80746835, 0.7940446 , 0.71843153],
#        [0.98986363, 0.7502352 , 0.71447086],
#        [0.7367338 , 0.6946564 , 0.5890288 ],
#        [0.74631566, 0.71608806, 0.69786024],
#        [0.7168916 , 0.6663858 , 0.63892573],
#        [0.6652564 , 0.64884144, 0.63191587],
#        [0.7294992 , 0.7158763 , 0.68744826],
#        [0.76066923, 0.7347819 , 0.68657994],
#        [0.9738168 , 0.96814936, 0.92389345],
#        [0.8561145 , 0.78004354, 0.7006012 ],
#        [0.9242588 , 0.894904  , 0.8711472 ],
#        [0.9736803 , 0.9654495 , 0.9390975 ],
#        [0.8629625 , 0.78729343, 0.72707796],
#        [0.89007574, 0.6214291 , 0.61833817],
#        [0.88804114, 0.79554826, 0.7138976 ],
#        [0.951171  , 0.93634087, 0.81913984],
#        [0.81713206, 0.76714253, 0.76394403],
#        [0.8640757 , 0.71128166, 0.67734474],
#        [0.77359545, 0.7350665 , 0.71853596],
#        [0.9482057 , 0.94110525, 0.9295021 ],
#        [0.84542066, 0.8150382 , 0.78028256],
#        [0.9145846 , 0.9066653 , 0.89687437],
#        [0.92927647, 0.9036244 , 0.8030768 ],
#        [0.7882672 , 0.7114865 , 0.7090435 ],
#        [0.8933488 , 0.8409809 , 0.8270667 ],
#        [0.8905049 , 0.8715854 , 0.72026604],
#        [0.6932941 , 0.66226244, 0.64080924],
#        [0.8960663 , 0.8419477 , 0.77946985],
#        [0.7600547 , 0.68545884, 0.67195964],
#        [0.8022307 , 0.7817045 , 0.72020596],
#        [0.80055726, 0.7851928 , 0.615751  ],
#        [0.9398196 , 0.90130156, 0.8761214 ],
#        [0.878777  , 0.8457257 , 0.8453686 ],
#        [0.8261401 , 0.6282783 , 0.58773434],
#        [0.90862375, 0.9075296 , 0.6868984 ],
#        [0.95449674, 0.9478026 , 0.9150654 ],
#        [0.9083107 , 0.9006752 , 0.8548898 ],
#        [0.8191314 , 0.7750537 , 0.69590455],
#        [0.6761811 , 0.59055096, 0.58472425],
#        [0.7865602 , 0.6552933 , 0.64019644],
#        [0.8217565 , 0.8082399 , 0.7756386 ],
#        [0.9695257 , 0.94367635, 0.80638546],
#        [0.86187005, 0.6909866 , 0.68079925],
#        [0.94323975, 0.8916828 , 0.86203295],
#        [0.7568373 , 0.69539994, 0.6808973 ],
#        [0.74183327, 0.62993556, 0.6284616 ],
#        [0.76701975, 0.71819425, 0.65490973],
#        [0.7262942 , 0.58276993, 0.5196507 ],
#        [0.8192743 , 0.8109178 , 0.8011657 ],
#        [0.9199842 , 0.83080286, 0.7325672 ],
#        [0.74852693, 0.6889399 , 0.6800844 ],
#        [0.8204154 , 0.8124953 , 0.735058  ],
#        [0.90837073, 0.89054567, 0.836769  ],
#        [0.91207856, 0.75112826, 0.6595779 ],
#        [0.9816939 , 0.86219573, 0.8344982 ],
#        [0.865674  , 0.85477746, 0.6285321 ],
#        [0.7380014 , 0.73259664, 0.7102302 ],
#        [0.72579265, 0.6950816 , 0.68241566],
#        [0.9611841 , 0.95542234, 0.9308729 ],
#        [0.9198201 , 0.80267495, 0.7692729 ],
#        [0.96276796, 0.6876976 , 0.5858748 ],
#        [0.967768  , 0.9323509 , 0.8353004 ],
#        [0.8960123 , 0.87544507, 0.81890845],
#        [0.7224759 , 0.70526737, 0.6190067 ],
#        [0.9035273 , 0.8610251 , 0.84256107],
#        [0.75107294, 0.7419974 , 0.72077703],
#        [0.86740935, 0.85403675, 0.8389116 ],
#        [0.88922065, 0.7662577 , 0.7610029 ],
#        [0.91686803, 0.90603375, 0.8571675 ],
#        [0.880335  , 0.8184932 , 0.808754  ],
#        [0.76670784, 0.69272226, 0.640279  ],
#        [0.8729849 , 0.8440535 , 0.78553885],
#        [0.8183452 , 0.6643871 , 0.6134641 ]], dtype=float32)

# %%
img = io.imread("me.jpg")
img = transform.resize(img, (64, 64))
img = color.rgb2gray(img)

# %%
io.imshow(img)

# %%
test = pca.transform(img.reshape(1, -1))

# %%
test = test/np.sqrt(np.sum(np.square(test), axis = 1, keepdims = True))
test
# Out:
# array([[ 0.33665835,  0.47282442, -0.23819614,  0.09979169, -0.19632204,
#         -0.19620075, -0.16524712, -0.10356813, -0.08783556,  0.05537108,
#         -0.03917656,  0.10676648,  0.24757397,  0.10854035, -0.11355811,
#          0.01808032,  0.03702428, -0.02241678, -0.01048192, -0.06590597,
#         -0.07385216, -0.11253468, -0.03418898, -0.04624008,  0.01139094,
#         -0.06130981, -0.11152475,  0.00223469, -0.02165022, -0.09322972,
#          0.03798081,  0.01226595, -0.13899444, -0.09160968,  0.1090086 ,
#          0.04135848, -0.03876672, -0.0201953 ,  0.16042617, -0.06935602,
#          0.04144374, -0.01287944, -0.20812148,  0.00903462,  0.02694006,
#          0.00508937, -0.01631443, -0.00710237, -0.01392461, -0.00924446,
#         -0.05982181, -0.13817188,  0.10669072,  0.01446257, -0.02194312,
#         -0.03599571,  0.03126569,  0.07270822,  0.00683385, -0.00487461,
#         -0.09622656, -0.04894794,  0.1357646 , -0.11864192, -0.0105854 ,
#          0.08036218,  0.11582305, -0.01969036, -0.05502704,  0.00220429,
#         -0.09605546, -0.01920217,  0.04050978, -0.09511194, -0.07560237,
#          0.01617578,  0.04115665, -0.01608525, -0.02634682, -0.04774445,
#          0.0402456 ,  0.03385952, -0.02800755, -0.0824719 , -0.03494995,
#          0.0109792 ,  0.0447144 , -0.02026066,  0.00882677, -0.02449437,
#          0.01361935,  0.05686437, -0.02510594,  0.02511154, -0.03689023,
#         -0.0269332 , -0.03754724, -0.01326164,  0.01542987,  0.08151632,
#          0.07808869,  0.02158232, -0.02809986,  0.0547128 ,  0.05970583,
#          0.02110421, -0.03596906,  0.06078989,  0.00292005,  0.06196455,
#          0.04188019]])

# %%
n, d = GetNeighbors(x_train, y_train, test, 1)

# %%
if np.squeeze(d) < 0.6:
    print("Not recognized")
# Out:
# Not recognized
